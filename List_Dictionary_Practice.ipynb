# %% [markdown]
# # 📝 Practice: Python Lists and Dictionaries
# This notebook contains exercises to practice working with lists, dictionaries, and nested structures.

# %% [markdown]
# ## 📋 Task 1: Create a List
# Create a list named `colors` that contains the strings `'red'`, `'green'`, and `'blue'`.
# ✅ Print the list.

# %%
# TODO: Create and print the list

# %% [markdown]
# ## 🔁 Task 2: Modify the List
# - Change `'green'` to `'yellow'`
# - Add `'purple'` to the end of the list
# - Remove `'red'`
# ✅ Print the updated list.

# %%
# TODO: Modify the list as described

# %% [markdown]
# ## 🧱 Task 3: Create a Dictionary
# Create a dictionary named `student` with the following keys and values:
# - `'name'`: `'Alex'`
# - `'age'`: `21`
# - `'courses'`: a list of strings: `'Math'`, `'Biology'`
# ✅ Print the dictionary.

# %%
# TODO: Create and print the dictionary

# %% [markdown]
# ## ✍️ Task 4: Update the Dictionary
# - Add a new key `'graduated'` with value `False`
# - Change the `'age'` to `22`
# ✅ Print the updated dictionary.

# %%
# TODO: Update the dictionary as described

# %% [markdown]
# ## 🔁 Task 5: Loop Through a Dictionary
# Loop through all keys and values in the `student` dictionary and print them in the format:
# ```
# key: value
# ```

# %%
# TODO: Loop through dictionary

# %% [markdown]
# ## 🧪 Task 6: List of Dictionaries
# Create a list called `students` that contains **three dictionaries**, each with keys `'name'` and `'grade'`. Then loop over the list and print:
# ```
# Name: <name>, Grade: <grade>
# ```

# %%
# TODO: Create list of dicts and loop over it
